# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import numpy as np

import os

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Conv3D, MaxPooling3D, AveragePooling3D
from tensorflow.keras.models import Sequential, load_model
import SimpleITK as sitk
import nibabel as nib

np.random.seed(24)

# %%
image = sitk.ReadImage('../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/SerieMR-0005-0001-1.dcm')

# %%
image_array = sitk.GetArrayFromImage(image[:,:,0])

# %%
plt.imshow(image_array, cmap='gray')

# %%
image = nib.load('../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/t2_tse_tra_192_0005_t2_tse_tra_192_0_5.nii').get_fdata()
image.shape
# img_arr = sitk.GetArrayFromImage(image[:,:,0])
# plt.imshow(img_arr)
# Out:
# (192, 192, 120)

# %%
image_test = image[:,100,:]

# %%
image_rot = np.rot90(image_test)

# %%
plt.imshow(image_rot, cmap='gray')
plt.show()

# %%
Dcm2niix(source_dir='../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/',
         output_dir='../brain_images/test',
         compress='n')

# %%
# setting initial control scan path
control_dir = '../brain_images/no_known_disorder/cobre_07325/'

# setting total control patients
patients_c = [each for each in os.listdir(control_dir)]

# %%
# list of dicitionarys for control image arrays
for patient in patients_c:
    for session in os.listdir(control_dir+patient):
        for scan in os.listdir(control_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                try:
                    converter = Dcm2niix()
                    converter.inputs.source_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                    converter.inputs.compress = 'n'
                    converter.inputs.output_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                    converter.run()
                except:
                    print(f'Error for file: {each}')
# Out:
# 220225-23:54:45,349 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,367 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,389 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,412 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,438 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,462 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,490 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,516 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,541 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,573 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,600 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,632 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,666 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,692 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,729 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,762 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,789 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,829 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,858 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,896 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:45,943 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,40 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,66 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,104 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,155 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,203 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,229 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,313 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,358 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,407 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,436 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,489 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,545 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,664 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,789 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:46,929 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,8 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,82 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,202 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,310 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,358 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,416 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,456 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,663 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,714 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,776 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,896 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:47,979 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,9 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,124 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,242 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,291 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,375 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,416 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,462 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,503 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,591 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,714 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,783 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:48,831 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,1 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,46 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,103 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,263 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,329 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,471 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,586 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,611 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,752 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,869 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:49,895 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,40 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,71 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,135 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,227 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,264 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,290 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,331 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:54:50,469 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm

# %%
# setting initial schizophrenic image path
schiz_dir = '../brain_images/schizophrenic/cobre_07325/'

# setting total schizophrenic patients
patients_s = [each for each in os.listdir(schiz_dir)]

# %%
# list of dictionaries for all schizophrenic image arrays
for patient in patients_s:
    for session in os.listdir(schiz_dir+patient):
        for scan in os.listdir(schiz_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                try:
                    converter = Dcm2niix()
                    converter.inputs.source_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.inputs.compress = 'n'
                    converter.inputs.output_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.run()
                except:
                    print(f'Error for file: {each}')
# Out:
# 220225-23:57:52,792 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,812 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,834 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,860 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,886 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,916 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:52,965 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,16 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,149 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,184 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,228 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,278 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,305 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,359 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,388 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,417 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,478 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,550 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,594 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,627 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,683 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,777 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,883 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:53,925 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,31 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,63 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,201 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,232 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,316 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,345 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,421 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,504 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,546 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,584 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,665 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,746 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,881 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:54,965 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,63 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,114 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,173 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,253 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,364 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,566 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,608 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,707 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,776 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:55,876 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,15 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,125 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,183 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,350 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,385 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,554 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,599 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,637 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,736 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,765 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,847 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:56,891 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,10 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,48 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,158 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,203 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,364 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,409 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220225-23:57:57,474 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm

# %%
for patient in patients_c:
    for session in os.listdir(control_dir+patient):
        for scan in os.listdir(control_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                for each in os.listdir(control_dir+patient+'/'+session+'/'+scan+'/'):
                    if 'nii' in each:
                        # print(each)
                        os.remove(control_dir+patient+'/'+session+'/'+scan+'/'+each)

# %%
converter = Dcm2niix()
converter.inputs.source_dir = '../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/'
converter.inputs.compress = 'n'
converter.inputs.output_dir = '../brain_images/test/'
converter.run()
# Out:
# 220225-23:43:47,780 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16816/2356866442.py in <module>
#       3 converter.inputs.compress = 'n'
#       4 converter.inputs.output_dir = '../brain_images/test/'
# ----> 5 converter.run()
#
# ~\anaconda3\lib\site-packages\nipype\interfaces\base\core.py in run(self, cwd, ignore_exception, **inputs)
#     396             # Run interface
#     397             runtime = self._pre_run_hook(runtime)
# --> 398             runtime = self._run_interface(runtime)
#     399             runtime = self._post_run_hook(runtime)
#     400             # Collect outputs
#
# ~\anaconda3\lib\site-packages\nipype\interfaces\dcm2nii.py in _run_interface(self, runtime)
#     441     def _run_interface(self, runtime):
#     442         # may use return code 1 despite conversion
# --> 443         runtime = super(Dcm2niix, self)._run_interface(
#     444             runtime, correct_return_codes=(0, 1)
#     445         )
#
# ~\anaconda3\lib\site-packages\nipype\interfaces\base\core.py in _run_interface(self, runtime, correct_return_codes)
#     743             else "<skipped>"
#     744         )
# --> 745         runtime = run_command(runtime, output=self.terminal_output)
#     746         return runtime
#     747
#
# ~\anaconda3\lib\site-packages\nipype\utils\subprocess.py in run_command(runtime, output, timeout)
#     135         while proc.returncode is None:
#     136             proc.poll()
# --> 137             _process()
#     138
#     139         _process(drain=1)
#
# ~\anaconda3\lib\site-packages\nipype\utils\subprocess.py in _process(drain)
#     122         def _process(drain=0):
#     123             try:
# --> 124                 res = select.select(streams, [], [], timeout)
#     125             except select.error as e:
#     126                 iflogger.info(e)
#
# OSError: [WinError 10038] An operation was attempted on something that is not a socket

# %%
# setting initial control scan path
control_dir = '../brain_images/no_known_disorder/cobre_07325/'

# setting total control patients
patients_c = [each for each in os.listdir(control_dir)]

# %%
# list of dicitionarys for control image arrays
control_arrays_dict = []
for patient in patients_c:
    for session in os.listdir(control_dir+patient):
        for scan in os.listdir(control_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                # print(scan)
                try:
                    converter = Dcm2niix()
                    converter.inputs.source_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                    converter.inputs.compress = 'n'
                    converter.inputs.output_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                    converter.run()
                except:
                    print(f'Error for file: {each}')
# Out:
# 220226-02:24:21,771 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,791 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,811 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,834 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,856 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,879 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,902 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,943 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:21,973 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,3 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,40 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,94 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,124 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,172 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,240 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,337 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,425 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,507 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,544 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,643 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,778 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,903 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:22,959 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,25 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,170 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,324 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,377 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,513 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,610 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,719 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,836 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,870 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:23,974 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,13 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,71 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,111 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,173 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,201 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,248 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,298 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,437 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,491 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,537 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,599 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,646 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,746 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,880 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:24,986 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,18 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,87 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,135 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,241 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,271 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,324 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,385 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,473 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,551 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,586 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,624 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,701 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,731 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,762 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:25,913 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,39 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,200 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,245 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,276 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,403 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,450 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,650 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,689 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,752 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,896 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:26,990 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:27,78 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:27,143 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:27,238 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:27,279 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:24:27,375 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm

# %%
# setting initial schizophrenic image path
schiz_dir = '../brain_images/schizophrenic/cobre_07325/'

# setting total schizophrenic patients
patients_s = [each for each in os.listdir(schiz_dir)]

# %%
from nipype.interfaces.dcm2nii import Dcm2niix

# %%
# list of dictionaries for all schizophrenic image arrays
schiz_arrays_dict = []
for patient in patients_s:
    for session in os.listdir(schiz_dir+patient):
        for scan in os.listdir(schiz_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                # print(scan)
                try:
                    converter = Dcm2niix()
                    converter.inputs.source_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.inputs.compress = 'n'
                    converter.inputs.output_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.run()
                except:
                    print(f'Error for file: {each}')
# Out:
# 220226-02:22:40,231 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,254 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,274 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,298 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,324 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,362 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,407 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,434 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,477 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,507 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,546 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,602 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,696 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,725 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,802 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,928 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,971 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,32 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,127 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,161 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,202 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,306 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,379 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,453 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,496 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,526 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,554 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,619 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,741 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,769 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,805 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,856 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,885 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,958 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,992 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,47 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,84 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,115 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,148 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,194 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,247 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,329 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,448 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,599 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,674 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,794 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,914 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,969 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,26 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,64 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,161 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,238 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,276 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,348 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,379 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,459 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,506 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,686 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,756 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,829 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,971 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,0 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,31 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,79 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,124 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,164 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,237 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm

# %% [markdown]
# ### Start of Modeling Notebook (edit for submission)

# %%
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np

import os
import pandas as pd

from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, f1_score, precision_score, accuracy_score, recall_score, roc_curve, auc
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.models import Sequential, load_model
from tensorflow.math import confusion_matrix
from myscripts import array_dict, get_metrics_df, find_combined_img
import SimpleITK as sitk

np.random.seed(24)

# %% [markdown]
# ### Mprage CNN Model

# %% [markdown]
# #### Setting up model

# %%
control_array_dict = array_dict('control', 'mprage', 'all', 'dcm')

# %%
# creating a dataframe from list of dictionaries control group
control_df = pd.DataFrame(control_array_dict, columns=['path', 'scan'])

control_df['patient'] = [each[46:55] for each in control_df['path']]

control_df['study'] = [each[34:45] for each in control_df['path']]

control_df['scan_type'] = [each[66:79] for each in control_df['path']]

control_df['slice'] = [each[99:102] for each in control_df['path']]

control_df['schizophrenia'] = 0

# %%
schiz_array_dict = array_dict('schiz', 'mprage', 'all', 'dcm')
# Out:
# 22656 pictures converted.

# %%
# creating dataframe from list of dicionaries schiz group
schiz_df = pd.DataFrame(schiz_array_dict, columns=['path', 'scan'])

schiz_df['patient'] = [each[42:51] for each in schiz_df['path']]

schiz_df['study'] = [each[30:41] for each in schiz_df['path']]

schiz_df['scan_type'] = [each[62:75] for each in schiz_df['path']]

schiz_df['slice'] = [each[95:98] for each in schiz_df['path']]

schiz_df['schizophrenia'] = 1

# %%
# concating dataframes
mprage_df = pd.concat([schiz_df, control_df], axis=0)

# %%
mprage_df = mprage_df.drop(columns='path')

# %%
arrays = []
for each in mprage_df['scan']:
    arrays.append(each)

# %%
# saving mprage dataframe to csv
# saves a lot of space
mprage_df.to_csv('mprage_scans.csv')

# %%
mprage_df = pd.read_csv('mprage_scans.csv')

# %%
# setting X and y
X = arrays
y = mprage_df['schizophrenia']

# %% [markdown]
# #### Train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=24)

# %%
X_train = np.array(X_train).reshape(len(X_train), 256, 256, 1)

# %%
X_train.shape
# Out:
# (34128, 256, 256, 1)

# %%
X_test = np.array(X_test).reshape(len(X_test), 256, 256, 1)

# %%
X_test.shape
# Out:
# (11376, 256, 256, 1)

# %%
# saving X_train, y_train, X_test, y_test because computationally intensive
np.save('X_train', X_train)

np.save('X_test', X_test)

np.save('y_train', y_train)

np.save('y_test', y_test)

# %%
X_train = np.load('X_train.npy')

# %%
X_test = np.load('X_test.npy')

# %%
y_train = np.load('y_train.npy')

# %%
y_test = np.load('y_test.npy')

# %% [markdown]
# #### Modeling

# %%
model = Sequential()

# conv & pool
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=X_train[0].shape))
model.add(MaxPooling2D(pool_size=(2,2)))

# conv & pool
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# flatten & finish
model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid')) # binary classification

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 64)      640
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 492032)            0
#
#  dense (Dense)               (None, 64)                31490112
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 31,564,673
# Trainable params: 31,564,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 1067/1067 [==============================] - 2870s 3s/step - loss: 0.5026 - accuracy: 0.7146 - val_loss: 0.3141 - val_accuracy: 0.8345
# Epoch 2/10
# 1067/1067 [==============================] - 2792s 3s/step - loss: 0.2283 - accuracy: 0.8858 - val_loss: 0.1936 - val_accuracy: 0.9039
# Epoch 3/10
# 1067/1067 [==============================] - 2757s 3s/step - loss: 0.1319 - accuracy: 0.9363 - val_loss: 0.1974 - val_accuracy: 0.9147
# Epoch 4/10
# 1067/1067 [==============================] - 2742s 3s/step - loss: 0.1014 - accuracy: 0.9533 - val_loss: 0.1397 - val_accuracy: 0.9370
# Epoch 5/10
# 1067/1067 [==============================] - 2736s 3s/step - loss: 0.0706 - accuracy: 0.9658 - val_loss: 0.1315 - val_accuracy: 0.9424
# Epoch 6/10
# 1067/1067 [==============================] - 2721s 3s/step - loss: 0.0735 - accuracy: 0.9675 - val_loss: 0.1412 - val_accuracy: 0.9398
# Epoch 7/10
# 1067/1067 [==============================] - 2748s 3s/step - loss: 0.0558 - accuracy: 0.9755 - val_loss: 0.1495 - val_accuracy: 0.9423
# Epoch 8/10
# 1067/1067 [==============================] - 2721s 3s/step - loss: 0.0468 - accuracy: 0.9806 - val_loss: 0.1771 - val_accuracy: 0.9421
# Epoch 9/10
# 1067/1067 [==============================] - 2724s 3s/step - loss: 0.0398 - accuracy: 0.9837 - val_loss: 0.1719 - val_accuracy: 0.9466
# Epoch 10/10
# 1067/1067 [==============================] - 2724s 3s/step - loss: 0.0348 - accuracy: 0.9886 - val_loss: 0.1724 - val_accuracy: 0.9466

# %%
# saving full model
model.save('../models/model_full_mprage.h5')

# %% [markdown]
# ### FOR NEW NOTEBOOK

# %%
# setting initial control scan path
control_dir = '../brain_images/no_known_disorder/cobre_07325/'

# setting total control patients
patients_c = [each for each in os.listdir(control_dir)]

# %%
# list of dicitionarys for control image arrays
control_arrays_dict = []
for patient in patients_c:
    for session in os.listdir(control_dir+patient):
        for scan in os.listdir(control_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                image_c_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                for each in os.listdir(image_c_dir):
                    if "nii" in each:
                        try:
                            image = sitk.ReadImage(image_c_dir+each)
                            image_array = sitk.GetArrayFromImage(image)
                            image_flip = np.flip(image)
                            control_arrays_dict.append({'path': str(image_c_dir+each), 'scan': image_flip})
                        except:
                            print(f'Error for file: {each}')
print(f'{len(control_arrays_dict)} pictures converted.')
# Out:
# 79 pictures converted.

# %%
# setting initial schizophrenic image path
schiz_dir = '../brain_images/schizophrenic/cobre_07325/'

# setting total schizophrenic patients
patients_s = [each for each in os.listdir(schiz_dir)]

# %%
# list of dicitionarys for control image arrays
schiz_arrays_dict = []
for patient in patients_s:
    for session in os.listdir(schiz_dir+patient):
        for scan in os.listdir(schiz_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                image_s_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                for each in os.listdir(image_s_dir):
                    if "nii" in each:
                        try:
                            image = sitk.ReadImage(image_s_dir+each)
                            image_array = sitk.GetArrayFromImage(image)
                            image_flip = np.flip(image)
                            schiz_arrays_dict.append({'path': str(image_s_dir+each), 'scan': image_flip})
                        except:
                            print(f'Error for file: {each}')
print(f'{len(schiz_arrays_dict)} pictures converted.')
# Out:
# 67 pictures converted.

# %%
# combining control and schizophrenic scans
X = [each['scan'] for each in control_arrays_dict] + [each['scan'] for each in schiz_arrays_dict]

# convert to array and checking for shape of arrays
X_arr = np.array(X, dtype=object)
print(f'X shape: {X_arr.shape}')

# setting control scans to 0 and schizophrenic scans to 1
y = [0] * len(control_arrays_dict) + [1] * len(schiz_arrays_dict)

# convert to array and check shape
y = np.array(y)
print(f'y shape: {y.shape}')
# Out:
# X shape: (146, 4423680)
# y shape: (146,)

# %% [markdown]
# ### Train test split

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=24, stratify=y)

# %%
# reshape to prep for cnn
X_train = np.array(X_train).reshape(109, 192, 192, 120)

# %%
# checking shape
X_train.shape
# Out:
# (109, 192, 192, 120)

# %%
# reshape to prep for cnn
X_test = np.array(X_test).reshape(37, 192, 192, 120)

# %%
# checking shape
X_test.shape
# Out:
# (37, 192, 192, 120)

# %% [markdown]
# ### Baseline Model (3d)

# %%
model = Sequential()

# conv & pool
model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu', input_shape=X_train[0].shape))
model.add(AveragePooling2D(pool_size=(2,2)))

# conv & pool
model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu'))
model.add(AveragePooling2D(pool_size=(2,2)))

# flatten & finish
model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid')) # binary classification

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 190, 190, 64)      69184
#
#  average_pooling2d (AverageP  (None, 95, 95, 64)       0
#  ooling2D)
#
#  conv2d_3 (Conv2D)           (None, 93, 93, 128)       73856
#
#  average_pooling2d_1 (Averag  (None, 46, 46, 128)      0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 270848)            0
#
#  dense_2 (Dense)             (None, 64)                17334336
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17,477,441
# Trainable params: 17,477,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 14s 3s/step - loss: 14384.4561 - accuracy: 0.4862 - val_loss: 818.6246 - val_accuracy: 0.5405
# Epoch 2/10
# 4/4 [==============================] - 13s 3s/step - loss: 677.7670 - accuracy: 0.4862 - val_loss: 194.7544 - val_accuracy: 0.4865
# Epoch 3/10
# 4/4 [==============================] - 13s 3s/step - loss: 240.7955 - accuracy: 0.4312 - val_loss: 13.3596 - val_accuracy: 0.5946
# Epoch 4/10
# 4/4 [==============================] - 15s 4s/step - loss: 87.1284 - accuracy: 0.5321 - val_loss: 11.3811 - val_accuracy: 0.5405
# Epoch 5/10
# 4/4 [==============================] - 18s 4s/step - loss: 14.8301 - accuracy: 0.5413 - val_loss: 12.5962 - val_accuracy: 0.4595
# Epoch 6/10
# 4/4 [==============================] - 18s 4s/step - loss: 12.0230 - accuracy: 0.5138 - val_loss: 12.0389 - val_accuracy: 0.5405
# Epoch 7/10
# 4/4 [==============================] - 17s 4s/step - loss: 3.9540 - accuracy: 0.6055 - val_loss: 4.6829 - val_accuracy: 0.5405
# Epoch 8/10
# 4/4 [==============================] - 17s 4s/step - loss: 1.4607 - accuracy: 0.7064 - val_loss: 2.5201 - val_accuracy: 0.5135
# Epoch 9/10
# 4/4 [==============================] - 17s 4s/step - loss: 0.9796 - accuracy: 0.7798 - val_loss: 3.6397 - val_accuracy: 0.4324
# Epoch 10/10
# 4/4 [==============================] - 17s 4s/step - loss: 0.6886 - accuracy: 0.8165 - val_loss: 3.2897 - val_accuracy: 0.5135

# %% [markdown]
# ### RST

# %%
image = sitk.ReadImage('../brain_images/schizophrenic/cobre_07325/A00000368/Session_1/RSTpre_V01_R01_0011/RSTpre_V01_R01+CM.nii') 
img_arr = sitk.GetArrayFromImage(image)
print(img_arr.shape)
# Out:
# (150, 33, 64, 64)

# %%
# setting initial control scan path
control_dir = '../brain_images/no_known_disorder/cobre_07325/'

# setting total control patients
patients_c = [each for each in os.listdir(control_dir)][:12]

# %%
# list of dicitionarys for control image arrays
control_arrays_dict = []
for patient in patients_c:
    for session in os.listdir(control_dir+patient):
        for scan in os.listdir(control_dir+patient+'/'+session): 
            if "RSTpre_V01_" in scan:
                image_c_dir = control_dir+patient+'/'+session+'/'+scan+'/'
                for each in os.listdir(image_c_dir):
                    if "CM" in each:
                        try:
                            image = sitk.ReadImage(image_c_dir+each)
                            image_array = sitk.GetArrayFromImage(image)/255
                            control_arrays_dict.append({'path': str(image_c_dir+each), 'scan': image_array})
                        except:
                            print(f'Error for file: {each}')
print(f'{len(control_arrays_dict)} pictures converted.')
# Out:
# 10 pictures converted.

# %%
# setting initial schizophrenic image path
schiz_dir = '../brain_images/schizophrenic/cobre_07325/'

# setting total schizophrenic patients
patients_s = [each for each in os.listdir(schiz_dir)][:10]

# %%
# list of dicitionarys for control image arrays
schiz_arrays_dict = []
for patient in patients_s:
    for session in os.listdir(schiz_dir+patient):
        for scan in os.listdir(schiz_dir+patient+'/'+session): 
            if "RSTpre_V01_" in scan:
                image_s_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                for each in os.listdir(image_s_dir):
                    if "CM" in each:
                        try:
                            image = sitk.ReadImage(image_s_dir+each)
                            image_array = sitk.GetArrayFromImage(image)/255
                            schiz_arrays_dict.append({'path': str(image_s_dir+each), 'scan': image_array})
                        except:
                            print(f'Error for file: {each}')
print(f'{len(schiz_arrays_dict)} pictures converted.')
# Out:
# 10 pictures converted.

# %%
# combining control and schizophrenic scans
X = [each['scan'] for each in control_arrays_dict] + [each['scan'] for each in schiz_arrays_dict]

# convert to array and checking for shape of arrays
X_arr = np.array(X, dtype=object)
print(f'X shape: {X_arr.shape}')

# setting control scans to 0 and schizophrenic scans to 1
y = [0] * len(control_arrays_dict) + [1] * len(schiz_arrays_dict)

# convert to array and check shape
y = np.array(y)
print(f'y shape: {y.shape}')
# Out:
# X shape: (20, 150, 33, 64, 64)
# y shape: (20,)

# %% [markdown]
# ### Train test split

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=24, stratify=y)

# %%
# reshape to prep for cnn
X_train = np.array(X_train).reshape(15, 64, 64, 150, 33)

# %%
# checking shape
X_train.shape
# Out:
# (15, 64, 64, 150, 33)

# %%
# reshape to prep for cnn
X_test = np.array(X_test).reshape(5, 64, 64, 150, 33)

# %%
# checking shape
X_test.shape
# Out:
# (5, 64, 64, 150, 33)

# %% [markdown]
# ### Baseline Model (3d)

# %%
model = Sequential()

# conv & pool
model.add(Conv3D(filters=64, kernel_size=(3,3,3), activation='relu', input_shape=X_train[0].shape))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# conv & pool
model.add(Conv3D(filters=128, kernel_size=(3,3,3), activation='relu'))
model.add(MaxPooling3D(pool_size=(2,2,2)))

# flatten & finish
model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=1, activation='sigmoid')) # binary classification

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 62, 62, 148, 64)   57088
#
#  max_pooling3d_1 (MaxPooling  (None, 31, 31, 74, 64)   0
#  3D)
#
#  conv3d_4 (Conv3D)           (None, 29, 29, 72, 128)   221312
#
#  max_pooling3d_2 (MaxPooling  (None, 14, 14, 36, 128)  0
#  3D)
#
#  flatten (Flatten)           (None, 903168)            0
#
#  dense (Dense)               (None, 64)                57802816
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 58,081,281
# Trainable params: 58,081,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 103s 103s/step - loss: 3.6765 - accuracy: 0.6667 - val_loss: 42571.7773 - val_accuracy: 0.6000
# Epoch 2/10
# 1/1 [==============================] - 80s 80s/step - loss: 63191.0391 - accuracy: 0.4667 - val_loss: 3308.0867 - val_accuracy: 0.6000
# Epoch 3/10
# 1/1 [==============================] - 87s 87s/step - loss: 4927.9551 - accuracy: 0.4667 - val_loss: 2815.7751 - val_accuracy: 0.4000
# Epoch 4/10
# 1/1 [==============================] - 76s 76s/step - loss: 2341.0791 - accuracy: 0.5333 - val_loss: 370.0012 - val_accuracy: 0.4000
# Epoch 5/10
# 1/1 [==============================] - 81s 81s/step - loss: 307.5126 - accuracy: 0.5333 - val_loss: 1499.0067 - val_accuracy: 0.6000
# Epoch 6/10
# 1/1 [==============================] - 74s 74s/step - loss: 1985.2516 - accuracy: 0.4667 - val_loss: 735.1409 - val_accuracy: 0.6000
# Epoch 7/10
# 1/1 [==============================] - 80s 80s/step - loss: 929.3458 - accuracy: 0.4667 - val_loss: 116.1030 - val_accuracy: 0.4000
# Epoch 8/10
# 1/1 [==============================] - 76s 76s/step - loss: 89.6305 - accuracy: 0.5333 - val_loss: 115.8694 - val_accuracy: 0.4000
# Epoch 9/10
# 1/1 [==============================] - 77s 77s/step - loss: 91.8428 - accuracy: 0.5333 - val_loss: 73.0750 - val_accuracy: 0.6000
# Epoch 10/10
# 1/1 [==============================] - 76s 76s/step - loss: 85.0094 - accuracy: 0.4667 - val_loss: 47.6672 - val_accuracy: 0.6000

# %% [markdown]
# * Sample size too small to make inferences
# * Computationally intensive

# %%
image = nib.load('../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/t2_tse_tra_192_0005_t2_tse_tra_192_0_5.nii')
image.shape
# Out:
# (192, 192, 120)

# %%
image_array = np.asarray(image)

# %%
image_array = np.rot90(image_array)

# %%
image = sitk.ReadImage('../brain_images/no_known_disorder/cobre_07325/A00000300/Session_2/t2_tse_tra_192_0005/t2_tse_tra_192_0005_t2_tse_tra_192_0_5.nii') 
img_arr = sitk.GetArrayFromImage(image)
img_arr = np.flip(img_arr)
print(img_arr.shape)
# Out:
# (120, 192, 192)

# %%
image_rot_arr.shape
# Out:
# (192, 192, 120)

# %%
from nipype.interfaces.dcm2nii import Dcm2niix

# %%
# list of dictionaries for all schizophrenic image arrays
schiz_arrays_dict = []
for patient in patients_s:
    for session in os.listdir(schiz_dir+patient):
        for scan in os.listdir(schiz_dir+patient+'/'+session): 
            if "t2_tse_tra_192_0" in scan:
                # print(scan)
                try:
                    converter = Dcm2niix()
                    converter.inputs.source_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.inputs.compress = 'n'
                    converter.inputs.output_dir = schiz_dir+patient+'/'+session+'/'+scan+'/'
                    converter.run()
                except:
                    print(f'Error for file: {each}')
# Out:
# 220226-02:22:40,231 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,254 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,274 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,298 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,324 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,362 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,407 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,434 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,477 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,507 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,546 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,602 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,696 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,725 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,802 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,928 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:40,971 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,32 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,127 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,161 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,202 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,306 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,379 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,453 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,496 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,526 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,554 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,619 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,741 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,769 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,805 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,856 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,885 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,958 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:41,992 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,47 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,84 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,115 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,148 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,194 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,247 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,329 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,448 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,599 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,674 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,794 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,914 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:42,969 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,26 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,64 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,161 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,238 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,276 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,348 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,379 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,459 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,506 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,686 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,756 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,829 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:43,971 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,0 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,31 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,79 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,124 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,164 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm
# 220226-02:22:44,237 nipype.interface INFO:
# 	 [WinError 10038] An operation was attempted on something that is not a socket
# Error for file: SerieMR-0004-0120-1.dcm

# %%
from tensorflow import keras

# %%
model = load_model('../models/model_first_t2.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 190, 190, 64)      640
#
#  max_pooling2d (MaxPooling2D  (None, 95, 95, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 93, 93, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 46, 46, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 270848)            0
#
#  dense (Dense)               (None, 64)                17334336
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17,408,897
# Trainable params: 17,408,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dimensions
img_width = 192
img_height = 192

layer_name = 'conv3_block4_out'

# %%
model = keras.applications.ResNet50V2(weights='imagenet', include_top=False)

layer = model.get_layer(name=layer_name)
feature_extractor = keras.Model(inputs=model.inputs, outputs=layer.output)

# %%
def compute_loss(input_image, filter_index):
    activatoin = feature_extractor(input_image)
    filter_activation = activation[:, 2:-2, 2:-2, filter_index]
    return tf.reduce_mean(filter_activation)

# %%
def gradient_ascent_step(img, filter_index, learning_rate):
    with tf.GradientTape() as tape:
        tape.watch(img)
        loss = compute_loss(img, filter_index)
    # Compute gradients.
    grads = tape.gradient(loss, img)
    # Normalize gradients.
    grads = tf.math.l2_normalize(grads)
    img += learning_rate * grads
    return loss, img

# %%
def initialize_image():
    # We start from a gray image with some random noise
    img = tf.random.uniform((1, img_width, img_height, 3))
    # ResNet50V2 expects inputs in the range [-1, +1].
    # Here we scale our random inputs to [-0.125, +0.125]
    return (img - 0.5) * 0.25


def visualize_filter(filter_index):
    # We run gradient ascent for 20 steps
    iterations = 30
    learning_rate = 10.0
    img = initialize_image()
    for iteration in range(iterations):
        loss, img = gradient_ascent_step(img, filter_index, learning_rate)

    # Decode the resulting input image
    img = deprocess_image(img[0].numpy())
    return loss, img


def deprocess_image(img):
    # Normalize array: center on 0., ensure variance is 0.15
    img -= img.mean()
    img /= img.std() + 1e-5
    img *= 0.15

    # Center crop
    img = img[25:-25, 25:-25, :]

    # Clip to [0, 1]
    img += 0.5
    img = np.clip(img, 0, 1)

    # Convert to RGB array
    img *= 255
    img = np.clip(img, 0, 255).astype("uint8")
    return img

# %%
from IPython.display import Image, display

loss, img = visualize_filter(0)
keras.preprocessing.image.save_img("0.png", img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18476/3830990799.py in <module>
#       1 from IPython.display import Image, display
#       2
# ----> 3 loss, img = visualize_filter(0)
#       4 keras.preprocessing.image.save_img("0.png", img)
#
# ~\AppData\Local\Temp/ipykernel_18476/2497937808.py in visualize_filter(filter_index)
#      11     iterations = 30
#      12     learning_rate = 10.0
# ---> 13     img = initialize_image()
#      14     for iteration in range(iterations):
#      15         loss, img = gradient_ascent_step(img, filter_index, learning_rate)
#
# ~\AppData\Local\Temp/ipykernel_18476/2497937808.py in initialize_image()
#       1 def initialize_image():
#       2     # We start from a gray image with some random noise
# ----> 3     img = tf.random.uniform((1, img_width, img_height, 3))
#       4     # ResNet50V2 expects inputs in the range [-1, +1].
#       5     # Here we scale our random inputs to [-0.125, +0.125]
#
# NameError: name 'tf' is not defined

# %%
display(Image("0.png"))
